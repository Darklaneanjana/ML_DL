# %%
import pandas as pd
df = pd.read_csv('cereal_production_statistics_maha_season_2007.csv')

# %%
df
# Out:
#              DISTRICT   KURAKKAN AREA Hect.   KURAKKAN PROD. M.T.  \
# 0            COLOMBO                    NaN                   NaN
# 1            GAMPAHA                    NaN                   NaN
# 2            KALUTARA                   NaN                   NaN
# 3               KANDY                 144.0                 242.0
# 4              MATALE                 133.0                 181.0
# 5        NUWARA ELIYA                 164.0                  87.0
# 6               GALLE                   NaN                   NaN
# 7             MATARA                    4.0                   3.0
# 8          HAMBANTOTA                 531.0                 640.0
# 9             JAFFNA                   65.0                  44.0
# 10        KILINOCHCHI                  19.0                  11.0
# 11             MANNAR                   6.0                   3.0
# 12          VAVUNIYA                   84.0                  49.0
# ...
