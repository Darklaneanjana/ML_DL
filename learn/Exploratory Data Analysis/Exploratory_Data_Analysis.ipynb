# %%
# %pip install opendatasets
import opendatasets as od
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
plt.style.use('ggplot')
 
pd.set_option('display.max_columns', None)
# od.download('https://www.kaggle.com/code/robikscube/introduction-to-exploratory-data-analysis/data')

# %%
df = pd.read_csv('./coaster_db.csv')

# %%
df.head(5)
# Out:
#                              coaster_name          Length             Speed  \
# 0                      Switchback Railway  600 ft (180 m)  6 mph (9.7 km/h)
# 1                       Flip Flap Railway             NaN               NaN
# 2  Switchback Railway (Euclid Beach Park)             NaN               NaN
# 3            Loop the Loop (Coney Island)             NaN               NaN
# 4            Loop the Loop (Young's Pier)             NaN               NaN
#
#                          Location   Status   Opening date   Type  \
# 0                    Coney Island  Removed  June 16, 1884   Wood
# 1                   Sea Lion Park  Removed           1895   Wood
# 2  Cleveland, Ohio, United States   Closed            NaN  Other
# 3                           Other  Removed           1901  Steel
# 4                           Other  Removed           1901  Steel
#
#              Manufacturer Height restriction        Model        Height  \
# ...

# %%
df.dtypes
# Out:
# coaster_name                      object
# Length                            object
# Speed                             object
# Location                          object
# Status                            object
# Opening date                      object
# Type                              object
# Manufacturer                      object
# Height restriction                object
# Model                             object
# Height                            object
# Inversions                       float64
# Lift/launch system                object
# Cost                              object
# Trains                            object
# Park section                      object
# Duration                          object
# Capacity                          object
# G-force                           object
# Designer                          object
# Max vertical angle                object
# Drop                              object
# Soft opening date                 object
# ...

# %%
df = df[['coaster_name',
        #  'Length', 'Speed', 
        'Location', 'Status', 
        # 'Opening date','Type',
         'Manufacturer',
        #   'Height restriction', 'Model', 'Height',
    #    'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
    #    'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
    #    'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
    #    'Track layout', 'Fastrack available', 'Soft opening date.1',
    #    'Closing date',
    #  'Opened', 
    # 'Replaced by', 'Website',
    #    'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
    #    'Single rider line available', 'Restraint Style',
    #    'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
       'year_introduced', 'latitude', 'longitude', 'Type_Main',
       'opening_date_clean',
        # 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
       'speed_mph',
        # 'height_value', 'height_unit', 
        'height_ft',
       'Inversions_clean', 'Gforce_clean']].copy()

# %%
df.columns
# Out:
# Index(['coaster_name', 'Location', 'Status', 'Manufacturer', 'year_introduced',
#        'latitude', 'longitude', 'Type_Main', 'opening_date_clean', 'speed_mph',
#        'height_ft', 'Inversions_clean', 'Gforce_clean'],
#       dtype='object')

# %%
df['opening_date_clean'] = pd.to_datetime(df['opening_date_clean'])

# %%
df.rename(columns={'opening_date_clean': 'Opening_Date',
                    'year_introduced': 'Year_Introduced',
                    'Inversions_clean': 'Inversions',
                    'Gforce_clean': 'Gforce',
                    'coaster_name': 'Coaster_Name',
                    'speed_mph': 'Speed',
                    'height_ft': 'Height'}, inplace=True)

# %%
df.head(5)
# Out:
#                              Coaster_Name                        Location  \
# 0                      Switchback Railway                    Coney Island
# 1                       Flip Flap Railway                   Sea Lion Park
# 2  Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 3            Loop the Loop (Coney Island)                           Other
# 4            Loop the Loop (Young's Pier)                           Other
#
#     Status            Manufacturer  Year_Introduced  latitude  longitude  \
# 0  Removed  LaMarcus Adna Thompson             1884   40.5740   -73.9780
# 1  Removed            Lina Beecher             1895   40.5780   -73.9790
# 2   Closed                     NaN             1896   41.5800   -81.5700
# 3  Removed          Edwin Prescott             1901   40.5745   -73.9780
# 4  Removed          Edwin Prescott             1901   39.3538   -74.4342
#
#   Type_Main Opening_Date  Speed  Height  Inversions  Gforce
# ...

# %%
df.isna().sum()
# Out:
# Coaster_Name         0
# Location             0
# Status             213
# Manufacturer        59
# Year_Introduced      0
# latitude           275
# longitude          275
# Type_Main            0
# Opening_Date       250
# Speed              150
# Height             916
# Inversions           0
# Gforce             725
# dtype: int64

# %%
df.loc[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Coaster_Name, Location, Status, Manufacturer, Year_Introduced, latitude, longitude, Type_Main, Opening_Date, Speed, Height, Inversions, Gforce]
# Index: []

# %%
df.loc[~df.duplicated(subset=['Coaster_Name'])].reset_index(drop=True)
# Out:
#                                Coaster_Name                        Location  \
# 0                        Switchback Railway                    Coney Island
# 1                         Flip Flap Railway                   Sea Lion Park
# 2    Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 3              Loop the Loop (Coney Island)                           Other
# 4              Loop the Loop (Young's Pier)                           Other
# ..                                      ...                             ...
# 985            Ice Breaker (roller coaster)                SeaWorld Orlando
# 986                   Leviathan (Sea World)                       Sea World
# 987               Pantheon (roller coaster)      Busch Gardens Williamsburg
# 988                                 Tumbili                  Kings Dominion
# 989          Wonder Woman Flight of Courage        Six Flags Magic Mountain
#
# ...

# %% [markdown]
# ## Now feature understanding
# ### univarient analysis

# %%
df['Year_Introduced'].value_counts().head(10).plot(kind= 'barh', title='Top Years')
# Out:
# <AxesSubplot: >

# %%
df['Speed'].plot(kind='hist', bins = 20, title='Speed Distribution')
# Out:
# <AxesSubplot: title={'center': 'Speed Distribution'}, ylabel='Frequency'>

# %%
df['Speed'].plot(kind='kde', title='Speed Distribution', xlim=(0, 100))
# Out:
# <AxesSubplot: title={'center': 'Speed Distribution'}, ylabel='Density'>

# %%
df.head()
# Out:
#                              Coaster_Name                        Location  \
# 0                      Switchback Railway                    Coney Island
# 1                       Flip Flap Railway                   Sea Lion Park
# 2  Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 3            Loop the Loop (Coney Island)                           Other
# 4            Loop the Loop (Young's Pier)                           Other
#
#     Status            Manufacturer  Year_Introduced  latitude  longitude  \
# 0  Removed  LaMarcus Adna Thompson             1884   40.5740   -73.9780
# 1  Removed            Lina Beecher             1895   40.5780   -73.9790
# 2   Closed                     NaN             1896   41.5800   -81.5700
# 3  Removed          Edwin Prescott             1901   40.5745   -73.9780
# 4  Removed          Edwin Prescott             1901   39.3538   -74.4342
#
#   Type_Main Opening_Date  Speed  Height  Inversions  Gforce
# ...

# %%
df.plot(kind='scatter', x='Speed', y='Height', title='Speed vs Height')
plt.show()

# %%
sns.scatterplot(data=df, x='Speed', y='Height', hue='Type_Main', alpha=0.5)
# Out:
# <AxesSubplot: xlabel='Speed', ylabel='Height'>

# %%
sns.pairplot(df[['Speed', 'Height', 'Inversions', 'Gforce','Type_Main']], hue='Type_Main')
plt.show()

# %%
df[['Year_Introduced', 'Speed', 'Height', 'Inversions', 'Gforce']].dropna().corr()
# Out:
#                  Year_Introduced     Speed    Height  Inversions    Gforce
# Year_Introduced         1.000000  0.178619  0.145457   -0.172829  0.168763
# Speed                   0.178619  1.000000  0.734499   -0.026413  0.605090
# Height                  0.145457  0.734499  1.000000   -0.076255  0.460841
# Inversions             -0.172829 -0.026413 -0.076255    1.000000  0.270942
# Gforce                  0.168763  0.605090  0.460841    0.270942  1.000000

# %%
sns.heatmap(df[['Year_Introduced', 'Speed', 'Height', 'Inversions', 'Gforce']].dropna().corr(), annot=True)
# Out:
# <AxesSubplot: >
