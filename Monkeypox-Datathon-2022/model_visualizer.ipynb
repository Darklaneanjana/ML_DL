# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import tensorflow as tf
from tensorflow import keras
from keras import layers
from keras.models import Sequential
from keras.layers import Conv2D, GlobalAveragePooling2D, Dense, Dropout, Activation

import tensorboard

# %%
from keras.utils.vis_utils import model_to_dot
from IPython.display import SVG
SVG(model_to_dot(keras.applications.EfficientNetV2S(), show_shapes=True, show_layer_names=True, dpi=70).create(prog='dot', format='svg'))

# %%
from keras.utils.vis_utils import model_to_dot
from IPython.display import SVG
